# %%
# !git clone https://github.com/ultralytics/yolov5 #install Yolov5
# %cd yolov5 #change directory to Yolov5
# %pip install -qr requirements.txt # install dependencies
# Out:
# fatal: destination path 'yolov5' already exists and is not an empty directory.
# /home/work/Recycling/yolov5/yolov5/yolov5
# Note: you may need to restart the kernel to use updated packages.

# %%
clear_output()
print(f"Setup complete. Using torch {torch.__version__} ({torch.cuda.get_device_properties(0).name if torch.cuda.is_available() else 'CPU'})")
# Out:
# Setup complete. Using torch 1.9.0+cu111 (CUDA GPU)

# %% [markdown]
# # YoloV5L (pretrained weights batch size 20, img 450, all categories)

# %%
# !python train.py --img 450 --batch 20 --epochs 500 --data /home/work/Recycling/yolov5/data/taco3.yaml --cfg /home/work/Recycling/yolov5/models/yolov5l.yaml --weights yolov5x.pt
# Out:
# train: weights=yolov5x.pt, cfg=/home/work/Recycling/yolov5/models/yolov5l.yaml, data=/home/work/Recycling/yolov5/data/taco3.yaml, hyp=data/hyps/hyp.scratch.yaml, epochs=500, batch_size=20, imgsz=450, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, evolve=None, bucket=, cache=None, image_weights=False, device=, multi_scale=False, single_cls=False, adam=False, sync_bn=False, workers=8, project=runs/train, name=exp, exist_ok=False, quad=False, linear_lr=False, label_smoothing=0.0, patience=100, freeze=0, save_period=-1, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: up to date with https://github.com/ultralytics/yolov5 ✅
# YOLOv5 🚀 v6.0-25-g15e8c4c torch 1.9.0+cu111 CUDA:0 (CUDA GPU, 8130.666664123535MB)
#
# ...

# %% [markdown]
# # YoloV5L (pretrained weights yolo5x, batch size 20, img 450, 10 categories)

# %%
# !python train.py --img 450 --batch 20 --epochs 500 --data /home/work/Recycling/yolov5/data/taco10.yaml --cfg /home/work/Recycling/yolov5/models/yolov5l.yaml --weights yolov5x.pt
# Out:
# train: weights=yolov5x.pt, cfg=/home/work/Recycling/yolov5/models/yolov5l.yaml, data=/home/work/Recycling/yolov5/data/taco10.yaml, hyp=data/hyps/hyp.scratch.yaml, epochs=500, batch_size=20, imgsz=450, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, evolve=None, bucket=, cache=None, image_weights=False, device=, multi_scale=False, single_cls=False, adam=False, sync_bn=False, workers=8, project=runs/train, name=exp, exist_ok=False, quad=False, linear_lr=False, label_smoothing=0.0, patience=100, freeze=0, save_period=-1, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: remote: Enumerating objects: 57, done.
# remote: Counting objects: 100% (43/43), done.
# remote: Compressing objects: 100% (14/14), done.
# remote: Total 57 (delta 34), reused 34 (delta 29), pack-reused 14
# Command 'git fetch && git config --get remote.origin.url' timed out after 5 seconds
# ...

# %% [markdown]
# ### Previous model not finished due to time and computation limitations
